# %% [markdown]
# #Лабораторна робота №3. Зниження розмірності набору даних, отримання суттєвих ознак (feature extraction)

# %% [markdown]
# **Виконала** студентка групи КІ-41мп Додонова Марія.

# %% [markdown]
# ##Завдання

# %% [markdown]
# 1. Опрацювати матеріали уроків U-6, U-7, U-8.
# 2. Обрати одну з наступних задач та відповідно набір даних з багатьма ознаками:
# * Зменшення розмірності табличних даних.
# * Усунення шумів у зображеннях і реконструкція зображень. Оцінювання джерел із зашумлених вимірів.
# * Отримання ознак (feature extraction) із наборів зображень.
# * Отримання тем з наборів тексту (topic extraction).
#
# Дані для навчання можна обрати з репозиторію машинного навчання UCI:  https://archive.ics.uci.edu/datasets.
#
# 3. Виконати зниження розмірності набору даних, отримати суттєві ознаки (feature extraction), усунути шуми та ін. (залежно від обраної задачі), використовуючи декілька алгоритмів, реалізованих в scikit-learn python, з наступного переліку:
# * Метод головних компонент (PCA)
# * Зростаючий метод головних компонент (Incremental PCA)
# * PCA з рандомізованим розкладом за власними числами (singular value decomposition, SVD)
# * Розріджений метод головних компонент (SparsePCA та MiniBatchSparsePCA)
# * Ядерний метод головних компонент (Kernel PCA)
# * Усічений SVD і скритий семантичний аналіз (Truncated singular value decomposition and latent semantic analysis)
# * Словникове навчання (Dictionary Learning та MiniBatchDictionaryLearning)
# * Факторний аналіз (Factor Analysis, FA)
# * Аналіз незалежних компонент (Independent component analysis, ICA)
# * Метод матричної факторизації (Non-negative matrix factorization (NMF або NNMF))
# * Скритий розподіл Дирихле (Latent Dirichlet Allocation, LDA)
# * Лінійний та квадратичний дискримінантний аналіз (Linear and Quadratic Discriminant Analysis) - задача навчання з вчителем.
# 4. Виконати зниження розмірності набору даних, отримати суттєві ознаки (feature extraction), усунути шуми та ін. (залежно від обраної задачі), використовуючи
# * Автокодувальник з лінійними функціями активації.
# * Автокодувальник з нелінійними функціями активації.
# 5. Порівняти результати за різними алгоритмами. Для обраної задачі використати всі наведені вище алгоритми.
#
# Вказати які алгоритми дають кращі результати на обраному наборі даних. Чи є результати на основі автокодувальника з лінійними функціями активації близькими до результатів на основі методу PCA та інших з п.3?
#
# 6. Зробити висновки.

# %% [markdown]
# ##Виконання роботи

# %% [markdown]
# ###Вибір задачі та набору даних

# %% [markdown]
# Оберемо задачу зменшення розмірності табличних даних та набір даних з 21 ознакою Waveform Database Generator (Version 1) з репозиторію машинного навчання UCI: https://archive.ics.uci.edu/datasets.

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/waveform/waveform.data.Z
# !uncompress waveform.data.Z
# Out:
# --2025-03-18 18:10:44--  https://archive.ics.uci.edu/ml/machine-learning-databases/waveform/waveform.data.Z
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘waveform.data.Z’
#
# waveform.data.Z         [  <=>               ] 172.76K   784KB/s    in 0.2s
#
# 2025-03-18 18:10:44 (784 KB/s) - ‘waveform.data.Z’ saved [176908]
#
# gzip: waveform.data already exists; do you wish to overwrite (y or n)? y

# %%
import pandas as pd

column_names = [f"Attribute{i}" for i in range(1, 22)] + ["class"]
df = pd.read_csv("waveform.data", header=None, names=column_names)
df.head()
# Out:
#    Attribute1  Attribute2  Attribute3  Attribute4  Attribute5  Attribute6  \
# 0       -1.23       -1.56       -1.75       -0.28        0.60        2.22
# 1       -0.69        2.43        0.61        2.08        2.30        3.25
# 2       -0.12       -0.94        1.29        2.59        2.42        3.55
# 3        0.86        0.29        2.19       -0.02        1.13        2.51
# 4        1.16        0.37        0.40       -0.59        2.66        1.00
#
#    Attribute7  Attribute8  Attribute9  Attribute10  ...  Attribute13  \
# 0        0.85        0.21       -0.20         0.89  ...         2.89
# 1        5.52        4.55        2.97         2.22  ...         1.24
# 2        4.94        3.25        1.90         2.07  ...         2.50
# 3        2.37        5.45        5.45         4.84  ...         2.58
# 4        2.69        4.06        5.34         3.53  ...         4.30
#
#    Attribute14  Attribute15  Attribute16  Attribute17  Attribute18  \
# 0         7.75         4.59         3.15         5.12         3.32
# 1         1.89         1.88        -1.34         0.83         1.41
# 2         0.12         1.41         2.78         0.64         0.62
# 3         1.40         1.24         1.41         1.07        -1.43
# 4         1.84         1.73         0.21        -0.18         0.13
#
#    Attribute19  Attribute20  Attribute21  class
# 0         1.20         0.24        -0.56      2
# 1         1.78         0.60         2.42      1
# 2        -0.01        -0.79        -0.12      0
# 3         2.84        -1.18         1.12      1
# 4        -0.21        -0.80        -0.68      1
#
# [5 rows x 22 columns]

# %% [markdown]
# Розіб'ємо частину набору (1000 рядків) на навчальнний (70% даних) та тестовий (30% даних) піднабори. Виконаємо стандартизацію ознак.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X, y = df.iloc[:1000, :-1].values, df.iloc[:1000, -1].values

# Split data
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=0
)

# Feature standadization
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# Напишемо функції для побудови графіка поясненої та кумулятивної дисперсії, діаграми поверхні рішення та діаграми точності класифікації за результатами застосування різних алгоритмів.

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import numpy as np

def plot_variance(explained_variance_ratio):
  indices = range(1, 22)

  plt.figure(figsize=(10, 6))

  # Plot explained variance
  plt.bar(
      indices, explained_variance_ratio, alpha=0.5,
      align="center", label="Individual explained variance"
  )

  # Plot cumulative explained variance
  plt.step(
      indices, np.cumsum(explained_variance_ratio),
      where="mid", label="Cumulative explained variance"
  )

  plt.title("Explained and Cumulative Variance")
  plt.ylabel("Explained variance ratio")
  plt.xlabel("Principal component index")
  plt.legend(loc="center right")
  plt.tight_layout()

  plt.show()

def plot_decision_regions(X, y, classifier, resolution=0.02,
                          title="Decision Regions"):
  # Set markers and colors
  markers = ("s", "x", "o", "^", "v")
  colors = ("red", "blue", "lightgreen", "gray", "cyan")
  cmap = ListedColormap(colors[:len(np.unique(y))])

  # Plot decision surface
  x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
  x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
  xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                         np.arange(x2_min, x2_max, resolution))
  Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
  Z = Z.reshape(xx1.shape)
  plt.contourf(xx1, xx2, Z, alpha=0.4, cmap=cmap)
  plt.xlim(xx1.min(), xx1.max())
  plt.ylim(xx2.min(), xx2.max())

  # Plot examples by class
  for idx, cl in enumerate(np.unique(y)):
    plt.scatter(x=X[y == cl, 0], y=X[y == cl, 1],
                alpha=0.6, color=cmap(idx),
                marker=markers[idx], label=cl)

  plt.title(title)
  plt.xlabel("PC 1")
  plt.ylabel("PC 2")
  plt.legend(loc="lower left")
  plt.tight_layout()

  plt.show()

def plot_accuracy(algorithms, train_accuracies, test_accuracies):
  x = np.arange(len(algorithms))
  width = 0.4

  plt.figure(figsize=(10, 5))

  # Plot train and test accuracies
  plt.bar(x - width/2, train_accuracies, width=width,
          color="lightcoral", edgecolor="black", label="Train Accuracy")
  plt.bar(x + width/2, test_accuracies, width=width,
          color="skyblue", edgecolor="black", label="Test Accuracy")

  # Set y limits
  min_y = min(min(train_accuracies), min(test_accuracies)) - 0.01
  max_y = max(max(train_accuracies), max(test_accuracies)) + 0.01
  plt.ylim(min_y, max_y)

  plt.xticks(x, algorithms, rotation=45, ha="right")
  plt.grid(axis="y", linestyle="--", alpha=0.7)

  # Show accuracy values on the diagram
  for i in range(len(algorithms)):
    plt.text(x[i] - width/2, train_accuracies[i] + 0.002,
             f"{train_accuracies[i]:.3f}", ha="center", fontsize=9,
             fontweight="bold")
    plt.text(x[i] + width/2, test_accuracies[i] + 0.002,
             f"{test_accuracies[i]:.3f}", ha="center", fontsize=9,
             fontweight="bold")

  plt.title("Comparing Training and Testing Accuracies")
  plt.xlabel("Algorithm")
  plt.ylabel("Accuracy")
  plt.legend()

  plt.show()

# %% [markdown]
# Для перевірки та оцінки алгоритмів будемо використовувати функцію score_algorithm.

# %%
from sklearn.metrics import accuracy_score

def score_algorithm(algorithm, classifier,
                    X_train, y_train, X_test, y_test,
                    plot=True, mode="default"):
  if mode == "lda":
    X_train_transformed = algorithm.fit_transform(X_train, y_train)
    X_test_transformed = algorithm.transform(X_test)
  elif mode == "encoder":
    X_train_transformed = algorithm.predict(X_train)
    X_test_transformed = algorithm.predict(X_test)
  elif mode == "baseline":
    X_train_transformed = X_train.copy()
    X_test_transformed = X_test.copy()
  else:
    X_train_transformed = algorithm.fit_transform(X_train)
    X_test_transformed = algorithm.transform(X_test)

  # Fit classifier
  classifier = classifier.fit(X_train_transformed, y_train)

  y_train_pred = classifier.predict(X_train_transformed)
  y_test_pred = classifier.predict(X_test_transformed)

  # Calculate and print accuracies
  train_accuracy = accuracy_score(y_train, y_train_pred)
  test_accuracy = accuracy_score(y_test, y_test_pred)

  print(f"Train Accuracy: {train_accuracy:.4f}")
  print(f"Test Accuracy: {test_accuracy:.4f}")

  # Plot decision regions
  if plot:
    plot_decision_regions(X_train_transformed, y_train,
                          classifier=classifier,
                          title="Decision Regions on Train Dataset")
    plot_decision_regions(X_test_transformed, y_test,
                          classifier=classifier,
                          title="Decision Regions on Test Dataset")

  return train_accuracy, test_accuracy

# %% [markdown]
# Як класифікатор використовуватимемо модель логістичної регресії з методом оптимізації L-BFGS (Limited-memory Broyden-Fletcher-Goldfarb-Shanno). Для побудови діаграми точності класифікації за результатами застосування різних алгоритмів, зберігатимемо значення точностей у масивах.

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(random_state=1, solver="lbfgs")
algorithms, train_accuracies, test_accuracies = [], [], []

# %% [markdown]
# ###Зниження розмірності набору даних з використанням алгоритмів, реалізованих у scikit-learn

# %% [markdown]
# Виконаємо зниження розмірності набору даних, використовуючи Метод головних компонент (PCA), реалізований в scikit-learn python.
#
# Спершу створимо модель PCA без вказаного числа компонент та побудуємо графік поясненої дисперсії.

# %%
from sklearn.decomposition import PCA

pca = PCA()
X_train_pca = pca.fit_transform(X_train)

print("Explained Variance Ratio")
for i, r in enumerate(pca.explained_variance_ratio_):
  print(f"Attribute {i:2}: {r:.4f}")

plot_variance(pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratio
# Attribute  0: 0.3719
# Attribute  1: 0.1597
# Attribute  2: 0.0513
# Attribute  3: 0.0462
# Attribute  4: 0.0425
# Attribute  5: 0.0409
# Attribute  6: 0.0324
# Attribute  7: 0.0299
# Attribute  8: 0.0263
# Attribute  9: 0.0229
# Attribute 10: 0.0211
# Attribute 11: 0.0197
# Attribute 12: 0.0185
# Attribute 13: 0.0177
# Attribute 14: 0.0166
# Attribute 15: 0.0164
# Attribute 16: 0.0151
# Attribute 17: 0.0145
# Attribute 18: 0.0139
# Attribute 19: 0.0120
# Attribute 20: 0.0107

# %% [markdown]
# Бачимо, що на перші дві компоненти припадає більш ніж 50% дисперсії у наборі. Надалі використовуватимемо 2 компоненти.
#
# Застосуємо Метод головних компонент на даних для 2 компонент, обчислимо точність класифікатора та побудуємо діаграми поверхонь рішень.

# %%
pca = PCA(n_components=2)

scores = score_algorithm(pca, lr, X_train, y_train, X_test, y_test)

algorithms.append("PCA")
train_accuracies.append(scores[0])
test_accuracies.append(scores[1])
# Out:
# Train Accuracy: 0.8800
# Test Accuracy: 0.8533

# %% [markdown]
# Виконаємо зниження розмірності набору даних, використовуючи Зростаючий метод головних компонент (Incremental PCA) для 2 компонент, реалізований в scikit-learn python.

# %%
from sklearn.decomposition import IncrementalPCA

ipca = IncrementalPCA(n_components=2)
scores = score_algorithm(ipca, lr, X_train, y_train, X_test, y_test)

algorithms.append("Incremental PCA")
train_accuracies.append(scores[0])
test_accuracies.append(scores[1])
# Out:
# Train Accuracy: 0.8800
# Test Accuracy: 0.8500

# %% [markdown]
# Виконаємо зниження розмірності набору даних, використовуючи обидві версії Розрідженого методу головних компонент (SparsePCA та MiniBatchSparsePCA) для 2 компонент, реалізовані в scikit-learn python.

# %%
from sklearn.decomposition import SparsePCA, MiniBatchSparsePCA

spca = SparsePCA(n_components=2)
scores = score_algorithm(spca, lr, X_train, y_train, X_test, y_test)

algorithms.append("Sparse PCA")
train_accuracies.append(scores[0])
test_accuracies.append(scores[1])

mbspca = MiniBatchSparsePCA(n_components=2)
scores = score_algorithm(mbspca, lr, X_train, y_train, X_test, y_test)

algorithms.append("Mini Batch Sparse PCA")
train_accuracies.append(scores[0])
test_accuracies.append(scores[1])
# Out:
# Train Accuracy: 0.8800
# Test Accuracy: 0.8633
# Train Accuracy: 0.8800
# Test Accuracy: 0.8567

# %% [markdown]
# Виконаємо зниження розмірності набору даних, використовуючи Ядерний метод головних компонент (Kernel PCA) для 2 компонент, реалізований в scikit-learn python. Використаємо для нелінійного перетворення радіальну базисну функцію (RBF) з параметром gamma=0.005.

# %%
from sklearn.decomposition import KernelPCA

kpca = KernelPCA(n_components=2, kernel="rbf", gamma=0.005)
scores = score_algorithm(kpca, lr, X_train, y_train, X_test, y_test)

algorithms.append("Kernel PCA")
train_accuracies.append(scores[0])
test_accuracies.append(scores[1])
# Out:
# Train Accuracy: 0.8743
# Test Accuracy: 0.8633

# %% [markdown]
# Виконаємо зниження розмірності набору даних, використовуючи Усічений SVD (Truncated singular value decomposition) для 2 компонент, реалізований в scikit-learn python.

# %%
from sklearn.decomposition import TruncatedSVD

tsvd = TruncatedSVD(n_components=2)
scores = score_algorithm(tsvd, lr, X_train, y_train, X_test, y_test)

algorithms.append("Truncated SVD")
train_accuracies.append(scores[0])
test_accuracies.append(scores[1])
# Out:
# Train Accuracy: 0.8800
# Test Accuracy: 0.8533

# %% [markdown]
# Виконаємо зниження розмірності набору даних, використовуючи Факторний аналіз (Factor Analysis, FA) для 2 компонент, реалізований в scikit-learn python.

# %%
from sklearn.decomposition import FactorAnalysis

fa = FactorAnalysis(n_components=2)
scores = score_algorithm(fa, lr, X_train, y_train, X_test, y_test)

algorithms.append("Factor Analysis")
train_accuracies.append(scores[0])
test_accuracies.append(scores[1])
# Out:
# Train Accuracy: 0.8829
# Test Accuracy: 0.8467

# %% [markdown]
# Виконаємо зниження розмірності набору даних, використовуючи Аналіз незалежних компонент (Independent component analysis, ICA) для 2 компонент, реалізований в scikit-learn python.

# %%
from sklearn.decomposition import FastICA

ica = FastICA(n_components=2)
scores = score_algorithm(ica, lr, X_train, y_train, X_test, y_test)

algorithms.append("ICA")
train_accuracies.append(scores[0])
test_accuracies.append(scores[1])
# Out:
# Train Accuracy: 0.8800
# Test Accuracy: 0.8567

# %% [markdown]
# Виконаємо зниження розмірності набору даних, використовуючи Лінійний дискримінантний аналіз (Linear Discriminant Analysis - задача навчання з вчителем) для 2 компонент, реалізований в scikit-learn python.

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

lda = LinearDiscriminantAnalysis(n_components=2)

scores = score_algorithm(lda, lr, X_train, y_train, X_test, y_test,
                         mode="lda")

algorithms.append("Linear Discriminant Analysis")
train_accuracies.append(scores[0])
test_accuracies.append(scores[1])
# Out:
# Train Accuracy: 0.8786
# Test Accuracy: 0.8300

# %% [markdown]
# ###Зниження розмірності набору даних з використанням Автокодувальників

# %% [markdown]
# Виконаємо зниження розмірності набору даних, використовуючи Автокодувальник з лінійними функціями активації.
#
# Для отримання кодувальника, напишемо  функцію get_encoder.

# %%
import tensorflow as tf
from tensorflow import keras

def get_encoder(X_train, X_test, linear=True, n_components=2,
                learning_rate=0.001, n_iterations=300):
  n_inputs = X_train.shape[1]
  activation = "linear" if linear else "tanh"

  encoder = keras.models.Sequential([
      keras.layers.InputLayer(shape=[n_inputs]),
      keras.layers.Dense(n_components, activation=activation)
  ])

  decoder = keras.models.Sequential([
      keras.layers.Dense(n_inputs, activation=activation)
  ])

  autoencoder = keras.models.Sequential([encoder, decoder])

  optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
  autoencoder.compile(optimizer=optimizer, loss="mse")
  autoencoder.fit(X_train, X_train, epochs=n_iterations,
                  verbose=1, validation_data=(X_test, X_test))

  return encoder

# %% [markdown]
# Створимо та натренуємо Автокодувальник із лінійними функціями активації. У якості оптимізатора застосуємо Adam зі швидкістю навчання 0.001 та функцією втрат MSE. Тренуватимемо модель протягом 300 епох.

# %%
lin_encoder = get_encoder(X_train, X_test)
# Out:
# Epoch 1/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.3327 - val_loss: 1.2585
# Epoch 2/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2496 - val_loss: 1.1884
# Epoch 3/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2039 - val_loss: 1.1392
# Epoch 4/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1389 - val_loss: 1.1032
# Epoch 5/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1115 - val_loss: 1.0741
# Epoch 6/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0839 - val_loss: 1.0484
# Epoch 7/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0626 - val_loss: 1.0254
# Epoch 8/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0341 - val_loss: 1.0034
# Epoch 9/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0280 - val_loss: 0.9801
# Epoch 10/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9892 - val_loss: 0.9546
# Epoch 11/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9462 - val_loss: 0.9249
# Epoch 12/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9277 - val_loss: 0.8898
# Epoch 13/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8797 - val_loss: 0.8493
# Epoch 14/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8480 - val_loss: 0.8045
# Epoch 15/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7936 - val_loss: 0.7591
# Epoch 16/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7614 - val_loss: 0.7153
# Epoch 17/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7066 - val_loss: 0.6766
# Epoch 18/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6737 - val_loss: 0.6425
# Epoch 19/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6257 - val_loss: 0.6148
# Epoch 20/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6116 - val_loss: 0.5917
# Epoch 21/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5922 - val_loss: 0.5734
# Epoch 22/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5688 - val_loss: 0.5585
# Epoch 23/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5485 - val_loss: 0.5465
# Epoch 24/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5514 - val_loss: 0.5366
# Epoch 25/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5384 - val_loss: 0.5283
# Epoch 26/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5325 - val_loss: 0.5213
# Epoch 27/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5091 - val_loss: 0.5150
# Epoch 28/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5129 - val_loss: 0.5096
# Epoch 29/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4968 - val_loss: 0.5050
# Epoch 30/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4966 - val_loss: 0.5010
# Epoch 31/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4988 - val_loss: 0.4975
# Epoch 32/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4956 - val_loss: 0.4946
# Epoch 33/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4977 - val_loss: 0.4916
# Epoch 34/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4828 - val_loss: 0.4895
# Epoch 35/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4822 - val_loss: 0.4874
# Epoch 36/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4944 - val_loss: 0.4857
# Epoch 37/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4902 - val_loss: 0.4842
# Epoch 38/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4728 - val_loss: 0.4827
# Epoch 39/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4836 - val_loss: 0.4815
# Epoch 40/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4849 - val_loss: 0.4806
# Epoch 41/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4784 - val_loss: 0.4795
# Epoch 42/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4769 - val_loss: 0.4787
# Epoch 43/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4854 - val_loss: 0.4780
# Epoch 44/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4726 - val_loss: 0.4773
# Epoch 45/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4783 - val_loss: 0.4767
# Epoch 46/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4732 - val_loss: 0.4762
# Epoch 47/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4778 - val_loss: 0.4758
# Epoch 48/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4774 - val_loss: 0.4752
# Epoch 49/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4849 - val_loss: 0.4749
# Epoch 50/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4742 - val_loss: 0.4743
# Epoch 51/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4745 - val_loss: 0.4741
# Epoch 52/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4741 - val_loss: 0.4737
# Epoch 53/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4733 - val_loss: 0.4733
# Epoch 54/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4700 - val_loss: 0.4730
# Epoch 55/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.4719 - val_loss: 0.4727
# Epoch 56/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4796 - val_loss: 0.4724
# Epoch 57/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4679 - val_loss: 0.4724
# Epoch 58/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4793 - val_loss: 0.4721
# Epoch 59/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4665 - val_loss: 0.4718
# Epoch 60/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4724 - val_loss: 0.4718
# Epoch 61/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4737 - val_loss: 0.4714
# Epoch 62/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4664 - val_loss: 0.4712
# Epoch 63/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4678 - val_loss: 0.4714
# Epoch 64/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4748 - val_loss: 0.4708
# Epoch 65/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4709 - val_loss: 0.4709
# Epoch 66/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.4750 - val_loss: 0.4707
# Epoch 67/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4696 - val_loss: 0.4705
# Epoch 68/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4709 - val_loss: 0.4704
# Epoch 69/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4740 - val_loss: 0.4703
# Epoch 70/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4743 - val_loss: 0.4703
# Epoch 71/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4708 - val_loss: 0.4702
# Epoch 72/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4723 - val_loss: 0.4700
# Epoch 73/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4735 - val_loss: 0.4698
# Epoch 74/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4690 - val_loss: 0.4697
# Epoch 75/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4682 - val_loss: 0.4696
# Epoch 76/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4675 - val_loss: 0.4695
# Epoch 77/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4629 - val_loss: 0.4695
# Epoch 78/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4761 - val_loss: 0.4696
# Epoch 79/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4774 - val_loss: 0.4694
# Epoch 80/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4774 - val_loss: 0.4694
# Epoch 81/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4789 - val_loss: 0.4693
# Epoch 82/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4587 - val_loss: 0.4693
# Epoch 83/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4670 - val_loss: 0.4692
# Epoch 84/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4722 - val_loss: 0.4694
# Epoch 85/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4642 - val_loss: 0.4692
# Epoch 86/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4668 - val_loss: 0.4690
# Epoch 87/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4656 - val_loss: 0.4689
# Epoch 88/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4713 - val_loss: 0.4691
# Epoch 89/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4693 - val_loss: 0.4690
# Epoch 90/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4614 - val_loss: 0.4689
# Epoch 91/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4778 - val_loss: 0.4689
# Epoch 92/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4697 - val_loss: 0.4689
# Epoch 93/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4800 - val_loss: 0.4689
# Epoch 94/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4692 - val_loss: 0.4688
# Epoch 95/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4692 - val_loss: 0.4688
# Epoch 96/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4756 - val_loss: 0.4689
# Epoch 97/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4687 - val_loss: 0.4687
# Epoch 98/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4689 - val_loss: 0.4689
# Epoch 99/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4603 - val_loss: 0.4686
# Epoch 100/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4679 - val_loss: 0.4686
# Epoch 101/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4647 - val_loss: 0.4686
# Epoch 102/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4723 - val_loss: 0.4688
# Epoch 103/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4687 - val_loss: 0.4688
# Epoch 104/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4540 - val_loss: 0.4687
# Epoch 105/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4633 - val_loss: 0.4686
# Epoch 106/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4604 - val_loss: 0.4686
# Epoch 107/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4588 - val_loss: 0.4687
# Epoch 108/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4686 - val_loss: 0.4686
# Epoch 109/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4802 - val_loss: 0.4684
# Epoch 110/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4655 - val_loss: 0.4686
# Epoch 111/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4713 - val_loss: 0.4685
# Epoch 112/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4741 - val_loss: 0.4686
# Epoch 113/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4732 - val_loss: 0.4684
# Epoch 114/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4687 - val_loss: 0.4686
# Epoch 115/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4702 - val_loss: 0.4684
# Epoch 116/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4595 - val_loss: 0.4687
# Epoch 117/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4738 - val_loss: 0.4685
# Epoch 118/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4633 - val_loss: 0.4686
# Epoch 119/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4674 - val_loss: 0.4684
# Epoch 120/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4703 - val_loss: 0.4686
# Epoch 121/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4750 - val_loss: 0.4686
# Epoch 122/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4655 - val_loss: 0.4683
# Epoch 123/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4689 - val_loss: 0.4687
# Epoch 124/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4799 - val_loss: 0.4685
# Epoch 125/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4660 - val_loss: 0.4684
# Epoch 126/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4730 - val_loss: 0.4685
# Epoch 127/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4772 - val_loss: 0.4683
# Epoch 128/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4683 - val_loss: 0.4685
# Epoch 129/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4599 - val_loss: 0.4685
# Epoch 130/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4702 - val_loss: 0.4685
# Epoch 131/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4648 - val_loss: 0.4685
# Epoch 132/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4728 - val_loss: 0.4685
# Epoch 133/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4745 - val_loss: 0.4684
# Epoch 134/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4655 - val_loss: 0.4685
# Epoch 135/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4662 - val_loss: 0.4685
# Epoch 136/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4794 - val_loss: 0.4685
# Epoch 137/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4695 - val_loss: 0.4684
# Epoch 138/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4624 - val_loss: 0.4685
# Epoch 139/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4669 - val_loss: 0.4684
# Epoch 140/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4658 - val_loss: 0.4686
# Epoch 141/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4672 - val_loss: 0.4685
# Epoch 142/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4652 - val_loss: 0.4684
# Epoch 143/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4749 - val_loss: 0.4684
# Epoch 144/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4698 - val_loss: 0.4686
# Epoch 145/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4581 - val_loss: 0.4684
# Epoch 146/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4616 - val_loss: 0.4685
# Epoch 147/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4739 - val_loss: 0.4683
# Epoch 148/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4669 - val_loss: 0.4686
# Epoch 149/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4713 - val_loss: 0.4684
# Epoch 150/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4612 - val_loss: 0.4686
# Epoch 151/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4653 - val_loss: 0.4685
# Epoch 152/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4685 - val_loss: 0.4685
# Epoch 153/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4611 - val_loss: 0.4686
# Epoch 154/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4652 - val_loss: 0.4684
# Epoch 155/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4545 - val_loss: 0.4683
# Epoch 156/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4718 - val_loss: 0.4686
# Epoch 157/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.4676 - val_loss: 0.4684
# Epoch 158/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.4706 - val_loss: 0.4685
# Epoch 159/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.4641 - val_loss: 0.4684
# Epoch 160/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4639 - val_loss: 0.4683
# Epoch 161/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4680 - val_loss: 0.4686
# Epoch 162/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4659 - val_loss: 0.4685
# Epoch 163/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4632 - val_loss: 0.4684
# Epoch 164/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4670 - val_loss: 0.4686
# Epoch 165/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4573 - val_loss: 0.4686
# Epoch 166/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4749 - val_loss: 0.4685
# Epoch 167/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4713 - val_loss: 0.4684
# Epoch 168/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4764 - val_loss: 0.4684
# Epoch 169/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4788 - val_loss: 0.4683
# Epoch 170/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4578 - val_loss: 0.4687
# Epoch 171/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4715 - val_loss: 0.4685
# Epoch 172/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4689 - val_loss: 0.4684
# Epoch 173/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4671 - val_loss: 0.4685
# Epoch 174/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4598 - val_loss: 0.4685
# Epoch 175/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4700 - val_loss: 0.4684
# Epoch 176/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4728 - val_loss: 0.4684
# Epoch 177/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4693 - val_loss: 0.4684
# Epoch 178/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4710 - val_loss: 0.4684
# Epoch 179/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.4667 - val_loss: 0.4684
# Epoch 180/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.4676 - val_loss: 0.4686
# Epoch 181/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.4737 - val_loss: 0.4685
# Epoch 182/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4659 - val_loss: 0.4685
# Epoch 183/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.4681 - val_loss: 0.4686
# Epoch 184/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4706 - val_loss: 0.4684
# Epoch 185/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4687 - val_loss: 0.4684
# Epoch 186/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4692 - val_loss: 0.4684
# Epoch 187/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.4681 - val_loss: 0.4687
# Epoch 188/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4687 - val_loss: 0.4684
# Epoch 189/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4637 - val_loss: 0.4682
# Epoch 190/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4614 - val_loss: 0.4685
# Epoch 191/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4663 - val_loss: 0.4685
# Epoch 192/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4782 - val_loss: 0.4684
# Epoch 193/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4636 - val_loss: 0.4683
# Epoch 194/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4664 - val_loss: 0.4684
# Epoch 195/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4707 - val_loss: 0.4686
# Epoch 196/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4713 - val_loss: 0.4687
# Epoch 197/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.4665 - val_loss: 0.4684
# Epoch 198/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.4637 - val_loss: 0.4685
# Epoch 199/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4708 - val_loss: 0.4683
# Epoch 200/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4610 - val_loss: 0.4685
# Epoch 201/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4619 - val_loss: 0.4686
# Epoch 202/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4548 - val_loss: 0.4684
# Epoch 203/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4732 - val_loss: 0.4684
# Epoch 204/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4704 - val_loss: 0.4685
# Epoch 205/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4600 - val_loss: 0.4685
# Epoch 206/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4712 - val_loss: 0.4684
# Epoch 207/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4740 - val_loss: 0.4685
# Epoch 208/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4709 - val_loss: 0.4684
# Epoch 209/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4875 - val_loss: 0.4684
# Epoch 210/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.4682 - val_loss: 0.4684
# Epoch 211/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4689 - val_loss: 0.4685
# Epoch 212/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4649 - val_loss: 0.4684
# Epoch 213/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.4643 - val_loss: 0.4685
# Epoch 214/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4706 - val_loss: 0.4685
# Epoch 215/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4629 - val_loss: 0.4685
# Epoch 216/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4599 - val_loss: 0.4684
# Epoch 217/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4754 - val_loss: 0.4683
# Epoch 218/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4615 - val_loss: 0.4684
# Epoch 219/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4772 - val_loss: 0.4684
# Epoch 220/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4645 - val_loss: 0.4684
# Epoch 221/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4659 - val_loss: 0.4686
# Epoch 222/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4671 - val_loss: 0.4683
# Epoch 223/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4727 - val_loss: 0.4684
# Epoch 224/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4740 - val_loss: 0.4684
# Epoch 225/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4639 - val_loss: 0.4684
# Epoch 226/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4748 - val_loss: 0.4686
# Epoch 227/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4755 - val_loss: 0.4684
# Epoch 228/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4662 - val_loss: 0.4686
# Epoch 229/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4834 - val_loss: 0.4684
# Epoch 230/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4626 - val_loss: 0.4685
# Epoch 231/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4755 - val_loss: 0.4685
# Epoch 232/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4718 - val_loss: 0.4684
# Epoch 233/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4679 - val_loss: 0.4683
# Epoch 234/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4638 - val_loss: 0.4686
# Epoch 235/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4603 - val_loss: 0.4685
# Epoch 236/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4708 - val_loss: 0.4685
# Epoch 237/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4589 - val_loss: 0.4685
# Epoch 238/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4655 - val_loss: 0.4684
# Epoch 239/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4636 - val_loss: 0.4684
# Epoch 240/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4639 - val_loss: 0.4685
# Epoch 241/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4683 - val_loss: 0.4685
# Epoch 242/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4699 - val_loss: 0.4685
# Epoch 243/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4625 - val_loss: 0.4686
# Epoch 244/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4660 - val_loss: 0.4684
# Epoch 245/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4756 - val_loss: 0.4684
# Epoch 246/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4719 - val_loss: 0.4683
# Epoch 247/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4711 - val_loss: 0.4683
# Epoch 248/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4761 - val_loss: 0.4685
# Epoch 249/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.4757 - val_loss: 0.4685
# Epoch 250/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4676 - val_loss: 0.4685
# Epoch 251/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4713 - val_loss: 0.4685
# Epoch 252/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4659 - val_loss: 0.4685
# Epoch 253/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4614 - val_loss: 0.4685
# Epoch 254/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.4721 - val_loss: 0.4683
# Epoch 255/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4711 - val_loss: 0.4684
# Epoch 256/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4705 - val_loss: 0.4685
# Epoch 257/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4696 - val_loss: 0.4685
# Epoch 258/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4785 - val_loss: 0.4683
# Epoch 259/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4820 - val_loss: 0.4685
# Epoch 260/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4726 - val_loss: 0.4685
# Epoch 261/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4670 - val_loss: 0.4686
# Epoch 262/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4761 - val_loss: 0.4684
# Epoch 263/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4819 - val_loss: 0.4685
# Epoch 264/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4697 - val_loss: 0.4684
# Epoch 265/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4694 - val_loss: 0.4685
# Epoch 266/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4678 - val_loss: 0.4685
# Epoch 267/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4702 - val_loss: 0.4685
# Epoch 268/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4749 - val_loss: 0.4685
# Epoch 269/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4783 - val_loss: 0.4685
# Epoch 270/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4675 - val_loss: 0.4684
# Epoch 271/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4636 - val_loss: 0.4683
# Epoch 272/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4712 - val_loss: 0.4685
# Epoch 273/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.4709 - val_loss: 0.4686
# Epoch 274/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4747 - val_loss: 0.4684
# Epoch 275/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4717 - val_loss: 0.4683
# Epoch 276/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4659 - val_loss: 0.4684
# Epoch 277/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4715 - val_loss: 0.4686
# Epoch 278/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4644 - val_loss: 0.4684
# Epoch 279/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4688 - val_loss: 0.4685
# Epoch 280/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4624 - val_loss: 0.4685
# Epoch 281/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4601 - val_loss: 0.4685
# Epoch 282/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4683 - val_loss: 0.4683
# Epoch 283/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4740 - val_loss: 0.4685
# Epoch 284/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4723 - val_loss: 0.4684
# Epoch 285/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4703 - val_loss: 0.4685
# Epoch 286/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4736 - val_loss: 0.4684
# Epoch 287/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4808 - val_loss: 0.4685
# Epoch 288/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4749 - val_loss: 0.4686
# Epoch 289/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4712 - val_loss: 0.4685
# Epoch 290/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4727 - val_loss: 0.4685
# Epoch 291/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4819 - val_loss: 0.4684
# Epoch 292/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4735 - val_loss: 0.4685
# Epoch 293/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4662 - val_loss: 0.4685
# Epoch 294/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4652 - val_loss: 0.4684
# Epoch 295/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4811 - val_loss: 0.4685
# Epoch 296/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4621 - val_loss: 0.4685
# Epoch 297/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4596 - val_loss: 0.4684
# Epoch 298/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4654 - val_loss: 0.4685
# Epoch 299/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4721 - val_loss: 0.4685
# Epoch 300/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4700 - val_loss: 0.4686

# %% [markdown]
# Оцінимо точність класифікатора на даних, отриманих із кодувальника з лінійною функцією активації.

# %%
scores = score_algorithm(lin_encoder, lr,
                         X_train, y_train, X_test, y_test,
                         mode="encoder")

algorithms.append("Autoencoder (linear activation)")
train_accuracies.append(scores[0])
test_accuracies.append(scores[1])
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Train Accuracy: 0.8800
# Test Accuracy: 0.8533

# %% [markdown]
# Виконаємо зниження розмірності набору даних, використовуючи Автокодувальник з нелінійними функціями активації.
#
# Створимо та натренуємо Автокодувальник із нелінійними функціями активації tanh. У якості оптимізатора застосуємо Adam зі швидкістю навчання 0.001 та функцією втрат MSE. Тренуватимемо модель протягом 300 епох.

# %%
non_lin_encoder = get_encoder(X_train, X_test, linear=False)
# Out:
# Epoch 1/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0635 - val_loss: 1.0369
# Epoch 2/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0533 - val_loss: 1.0098
# Epoch 3/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0151 - val_loss: 0.9869
# Epoch 4/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9679 - val_loss: 0.9677
# Epoch 5/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9848 - val_loss: 0.9498
# Epoch 6/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9771 - val_loss: 0.9327
# Epoch 7/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9661 - val_loss: 0.9155
# Epoch 8/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9121 - val_loss: 0.8979
# Epoch 9/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9031 - val_loss: 0.8796
# Epoch 10/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8590 - val_loss: 0.8611
# Epoch 11/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8709 - val_loss: 0.8418
# Epoch 12/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8286 - val_loss: 0.8225
# Epoch 13/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8185 - val_loss: 0.8031
# Epoch 14/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8229 - val_loss: 0.7837
# Epoch 15/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8002 - val_loss: 0.7651
# Epoch 16/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7721 - val_loss: 0.7473
# Epoch 17/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7413 - val_loss: 0.7307
# Epoch 18/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7344 - val_loss: 0.7152
# Epoch 19/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7167 - val_loss: 0.7012
# Epoch 20/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6969 - val_loss: 0.6887
# Epoch 21/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6984 - val_loss: 0.6774
# Epoch 22/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6907 - val_loss: 0.6673
# Epoch 23/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6592 - val_loss: 0.6582
# Epoch 24/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6740 - val_loss: 0.6499
# Epoch 25/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6370 - val_loss: 0.6425
# Epoch 26/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6621 - val_loss: 0.6356
# Epoch 27/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6466 - val_loss: 0.6293
# Epoch 28/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6157 - val_loss: 0.6236
# Epoch 29/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6429 - val_loss: 0.6180
# Epoch 30/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6271 - val_loss: 0.6131
# Epoch 31/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6150 - val_loss: 0.6082
# Epoch 32/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6062 - val_loss: 0.6038
# Epoch 33/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6033 - val_loss: 0.5996
# Epoch 34/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5972 - val_loss: 0.5956
# Epoch 35/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5875 - val_loss: 0.5920
# Epoch 36/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5979 - val_loss: 0.5885
# Epoch 37/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6005 - val_loss: 0.5852
# Epoch 38/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5846 - val_loss: 0.5821
# Epoch 39/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5911 - val_loss: 0.5791
# Epoch 40/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5854 - val_loss: 0.5764
# Epoch 41/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.5853 - val_loss: 0.5738
# Epoch 42/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5812 - val_loss: 0.5713
# Epoch 43/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.5833 - val_loss: 0.5689
# Epoch 44/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5788 - val_loss: 0.5667
# Epoch 45/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5652 - val_loss: 0.5646
# Epoch 46/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5724 - val_loss: 0.5626
# Epoch 47/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5567 - val_loss: 0.5606
# Epoch 48/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5651 - val_loss: 0.5588
# Epoch 49/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5581 - val_loss: 0.5570
# Epoch 50/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5613 - val_loss: 0.5554
# Epoch 51/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5636 - val_loss: 0.5538
# Epoch 52/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5633 - val_loss: 0.5522
# Epoch 53/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5731 - val_loss: 0.5507
# Epoch 54/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5591 - val_loss: 0.5493
# Epoch 55/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5614 - val_loss: 0.5480
# Epoch 56/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5535 - val_loss: 0.5466
# Epoch 57/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5484 - val_loss: 0.5454
# Epoch 58/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5500 - val_loss: 0.5441
# Epoch 59/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5293 - val_loss: 0.5429
# Epoch 60/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5510 - val_loss: 0.5417
# Epoch 61/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5444 - val_loss: 0.5406
# Epoch 62/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5577 - val_loss: 0.5395
# Epoch 63/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5464 - val_loss: 0.5384
# Epoch 64/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5470 - val_loss: 0.5372
# Epoch 65/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5355 - val_loss: 0.5363
# Epoch 66/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5401 - val_loss: 0.5352
# Epoch 67/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5372 - val_loss: 0.5342
# Epoch 68/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5455 - val_loss: 0.5332
# Epoch 69/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5467 - val_loss: 0.5323
# Epoch 70/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5363 - val_loss: 0.5314
# Epoch 71/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5483 - val_loss: 0.5305
# Epoch 72/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5434 - val_loss: 0.5296
# Epoch 73/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5313 - val_loss: 0.5288
# Epoch 74/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5373 - val_loss: 0.5279
# Epoch 75/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5293 - val_loss: 0.5271
# Epoch 76/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5372 - val_loss: 0.5264
# Epoch 77/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5287 - val_loss: 0.5256
# Epoch 78/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5240 - val_loss: 0.5249
# Epoch 79/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5344 - val_loss: 0.5242
# Epoch 80/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5289 - val_loss: 0.5235
# Epoch 81/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5204 - val_loss: 0.5229
# Epoch 82/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5258 - val_loss: 0.5222
# Epoch 83/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5224 - val_loss: 0.5216
# Epoch 84/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5217 - val_loss: 0.5210
# Epoch 85/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5257 - val_loss: 0.5205
# Epoch 86/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5284 - val_loss: 0.5199
# Epoch 87/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5250 - val_loss: 0.5194
# Epoch 88/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5211 - val_loss: 0.5189
# Epoch 89/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5244 - val_loss: 0.5185
# Epoch 90/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5157 - val_loss: 0.5180
# Epoch 91/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5328 - val_loss: 0.5175
# Epoch 92/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5266 - val_loss: 0.5171
# Epoch 93/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5163 - val_loss: 0.5167
# Epoch 94/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5197 - val_loss: 0.5163
# Epoch 95/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5154 - val_loss: 0.5159
# Epoch 96/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5230 - val_loss: 0.5155
# Epoch 97/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5118 - val_loss: 0.5152
# Epoch 98/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5139 - val_loss: 0.5148
# Epoch 99/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5296 - val_loss: 0.5145
# Epoch 100/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5183 - val_loss: 0.5141
# Epoch 101/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5115 - val_loss: 0.5138
# Epoch 102/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5054 - val_loss: 0.5135
# Epoch 103/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5096 - val_loss: 0.5132
# Epoch 104/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5197 - val_loss: 0.5129
# Epoch 105/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5174 - val_loss: 0.5127
# Epoch 106/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5202 - val_loss: 0.5124
# Epoch 107/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5208 - val_loss: 0.5121
# Epoch 108/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5177 - val_loss: 0.5119
# Epoch 109/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5229 - val_loss: 0.5116
# Epoch 110/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5260 - val_loss: 0.5114
# Epoch 111/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5076 - val_loss: 0.5111
# Epoch 112/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5132 - val_loss: 0.5109
# Epoch 113/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5180 - val_loss: 0.5107
# Epoch 114/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5246 - val_loss: 0.5105
# Epoch 115/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5155 - val_loss: 0.5103
# Epoch 116/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5233 - val_loss: 0.5100
# Epoch 117/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5162 - val_loss: 0.5098
# Epoch 118/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5220 - val_loss: 0.5096
# Epoch 119/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5183 - val_loss: 0.5095
# Epoch 120/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5083 - val_loss: 0.5092
# Epoch 121/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5095 - val_loss: 0.5090
# Epoch 122/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5151 - val_loss: 0.5088
# Epoch 123/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5199 - val_loss: 0.5087
# Epoch 124/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5129 - val_loss: 0.5085
# Epoch 125/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5040 - val_loss: 0.5083
# Epoch 126/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5079 - val_loss: 0.5082
# Epoch 127/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5088 - val_loss: 0.5080
# Epoch 128/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5069 - val_loss: 0.5079
# Epoch 129/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5118 - val_loss: 0.5077
# Epoch 130/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5158 - val_loss: 0.5076
# Epoch 131/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5092 - val_loss: 0.5074
# Epoch 132/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5226 - val_loss: 0.5073
# Epoch 133/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5112 - val_loss: 0.5071
# Epoch 134/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5096 - val_loss: 0.5070
# Epoch 135/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5044 - val_loss: 0.5068
# Epoch 136/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5236 - val_loss: 0.5067
# Epoch 137/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5140 - val_loss: 0.5066
# Epoch 138/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5220 - val_loss: 0.5065
# Epoch 139/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5026 - val_loss: 0.5064
# Epoch 140/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.5123 - val_loss: 0.5062
# Epoch 141/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5102 - val_loss: 0.5061
# Epoch 142/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5137 - val_loss: 0.5060
# Epoch 143/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.5060 - val_loss: 0.5058
# Epoch 144/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5136 - val_loss: 0.5057
# Epoch 145/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4983 - val_loss: 0.5056
# Epoch 146/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5158 - val_loss: 0.5055
# Epoch 147/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5017 - val_loss: 0.5054
# Epoch 148/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5164 - val_loss: 0.5053
# Epoch 149/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5126 - val_loss: 0.5052
# Epoch 150/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5175 - val_loss: 0.5050
# Epoch 151/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5144 - val_loss: 0.5049
# Epoch 152/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5051 - val_loss: 0.5048
# Epoch 153/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5204 - val_loss: 0.5048
# Epoch 154/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5104 - val_loss: 0.5047
# Epoch 155/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5103 - val_loss: 0.5047
# Epoch 156/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5115 - val_loss: 0.5045
# Epoch 157/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5049 - val_loss: 0.5044
# Epoch 158/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5043 - val_loss: 0.5043
# Epoch 159/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5103 - val_loss: 0.5042
# Epoch 160/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5003 - val_loss: 0.5041
# Epoch 161/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5081 - val_loss: 0.5039
# Epoch 162/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5067 - val_loss: 0.5040
# Epoch 163/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5004 - val_loss: 0.5039
# Epoch 164/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5076 - val_loss: 0.5038
# Epoch 165/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5099 - val_loss: 0.5036
# Epoch 166/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5111 - val_loss: 0.5036
# Epoch 167/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5148 - val_loss: 0.5036
# Epoch 168/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5180 - val_loss: 0.5034
# Epoch 169/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5041 - val_loss: 0.5034
# Epoch 170/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5059 - val_loss: 0.5033
# Epoch 171/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5056 - val_loss: 0.5032
# Epoch 172/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5124 - val_loss: 0.5032
# Epoch 173/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5094 - val_loss: 0.5031
# Epoch 174/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5035 - val_loss: 0.5030
# Epoch 175/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5113 - val_loss: 0.5029
# Epoch 176/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5004 - val_loss: 0.5029
# Epoch 177/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5047 - val_loss: 0.5028
# Epoch 178/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5072 - val_loss: 0.5027
# Epoch 179/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5081 - val_loss: 0.5027
# Epoch 180/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4999 - val_loss: 0.5027
# Epoch 181/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5040 - val_loss: 0.5026
# Epoch 182/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5054 - val_loss: 0.5025
# Epoch 183/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5047 - val_loss: 0.5025
# Epoch 184/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5041 - val_loss: 0.5024
# Epoch 185/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5085 - val_loss: 0.5023
# Epoch 186/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4854 - val_loss: 0.5022
# Epoch 187/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5058 - val_loss: 0.5022
# Epoch 188/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5021 - val_loss: 0.5021
# Epoch 189/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5052 - val_loss: 0.5021
# Epoch 190/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5008 - val_loss: 0.5020
# Epoch 191/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5019 - val_loss: 0.5019
# Epoch 192/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5023 - val_loss: 0.5019
# Epoch 193/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4966 - val_loss: 0.5019
# Epoch 194/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5083 - val_loss: 0.5018
# Epoch 195/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4991 - val_loss: 0.5018
# Epoch 196/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4973 - val_loss: 0.5017
# Epoch 197/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5073 - val_loss: 0.5017
# Epoch 198/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5162 - val_loss: 0.5016
# Epoch 199/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5095 - val_loss: 0.5016
# Epoch 200/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4996 - val_loss: 0.5015
# Epoch 201/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5041 - val_loss: 0.5014
# Epoch 202/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5142 - val_loss: 0.5014
# Epoch 203/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5078 - val_loss: 0.5014
# Epoch 204/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5123 - val_loss: 0.5013
# Epoch 205/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5077 - val_loss: 0.5013
# Epoch 206/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5011 - val_loss: 0.5012
# Epoch 207/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5118 - val_loss: 0.5012
# Epoch 208/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5060 - val_loss: 0.5011
# Epoch 209/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5138 - val_loss: 0.5011
# Epoch 210/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5049 - val_loss: 0.5010
# Epoch 211/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4978 - val_loss: 0.5010
# Epoch 212/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5046 - val_loss: 0.5009
# Epoch 213/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5001 - val_loss: 0.5009
# Epoch 214/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5175 - val_loss: 0.5009
# Epoch 215/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5130 - val_loss: 0.5009
# Epoch 216/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5002 - val_loss: 0.5008
# Epoch 217/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5112 - val_loss: 0.5007
# Epoch 218/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5075 - val_loss: 0.5007
# Epoch 219/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5011 - val_loss: 0.5007
# Epoch 220/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5018 - val_loss: 0.5007
# Epoch 221/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4933 - val_loss: 0.5006
# Epoch 222/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5036 - val_loss: 0.5005
# Epoch 223/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5092 - val_loss: 0.5006
# Epoch 224/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4999 - val_loss: 0.5004
# Epoch 225/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4990 - val_loss: 0.5004
# Epoch 226/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5009 - val_loss: 0.5004
# Epoch 227/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5017 - val_loss: 0.5004
# Epoch 228/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5054 - val_loss: 0.5004
# Epoch 229/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4893 - val_loss: 0.5003
# Epoch 230/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5111 - val_loss: 0.5003
# Epoch 231/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5097 - val_loss: 0.5002
# Epoch 232/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5040 - val_loss: 0.5003
# Epoch 233/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4990 - val_loss: 0.5001
# Epoch 234/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4977 - val_loss: 0.5001
# Epoch 235/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5023 - val_loss: 0.5001
# Epoch 236/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5121 - val_loss: 0.5001
# Epoch 237/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4998 - val_loss: 0.5001
# Epoch 238/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4983 - val_loss: 0.5001
# Epoch 239/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5052 - val_loss: 0.5000
# Epoch 240/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5021 - val_loss: 0.4999
# Epoch 241/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5139 - val_loss: 0.4999
# Epoch 242/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5058 - val_loss: 0.5000
# Epoch 243/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5073 - val_loss: 0.4998
# Epoch 244/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5062 - val_loss: 0.4999
# Epoch 245/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5088 - val_loss: 0.4998
# Epoch 246/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5084 - val_loss: 0.4997
# Epoch 247/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5044 - val_loss: 0.4997
# Epoch 248/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5102 - val_loss: 0.4998
# Epoch 249/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5051 - val_loss: 0.4997
# Epoch 250/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4996 - val_loss: 0.4997
# Epoch 251/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5106 - val_loss: 0.4997
# Epoch 252/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5111 - val_loss: 0.4997
# Epoch 253/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5140 - val_loss: 0.4997
# Epoch 254/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4935 - val_loss: 0.4995
# Epoch 255/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5052 - val_loss: 0.4995
# Epoch 256/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4977 - val_loss: 0.4995
# Epoch 257/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5095 - val_loss: 0.4995
# Epoch 258/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4970 - val_loss: 0.4995
# Epoch 259/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5039 - val_loss: 0.4994
# Epoch 260/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5081 - val_loss: 0.4994
# Epoch 261/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5088 - val_loss: 0.4994
# Epoch 262/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5052 - val_loss: 0.4994
# Epoch 263/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5016 - val_loss: 0.4994
# Epoch 264/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5006 - val_loss: 0.4993
# Epoch 265/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4999 - val_loss: 0.4993
# Epoch 266/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5079 - val_loss: 0.4992
# Epoch 267/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5028 - val_loss: 0.4993
# Epoch 268/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4979 - val_loss: 0.4993
# Epoch 269/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5027 - val_loss: 0.4992
# Epoch 270/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4940 - val_loss: 0.4992
# Epoch 271/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5042 - val_loss: 0.4992
# Epoch 272/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4986 - val_loss: 0.4991
# Epoch 273/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5086 - val_loss: 0.4991
# Epoch 274/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5012 - val_loss: 0.4990
# Epoch 275/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4919 - val_loss: 0.4991
# Epoch 276/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4935 - val_loss: 0.4990
# Epoch 277/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5052 - val_loss: 0.4991
# Epoch 278/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4976 - val_loss: 0.4990
# Epoch 279/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5102 - val_loss: 0.4990
# Epoch 280/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5078 - val_loss: 0.4991
# Epoch 281/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4972 - val_loss: 0.4990
# Epoch 282/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5052 - val_loss: 0.4990
# Epoch 283/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4991 - val_loss: 0.4989
# Epoch 284/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5006 - val_loss: 0.4989
# Epoch 285/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5074 - val_loss: 0.4989
# Epoch 286/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5049 - val_loss: 0.4989
# Epoch 287/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5039 - val_loss: 0.4988
# Epoch 288/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5051 - val_loss: 0.4989
# Epoch 289/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4940 - val_loss: 0.4988
# Epoch 290/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5097 - val_loss: 0.4987
# Epoch 291/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5028 - val_loss: 0.4988
# Epoch 292/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5067 - val_loss: 0.4987
# Epoch 293/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5043 - val_loss: 0.4987
# Epoch 294/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4982 - val_loss: 0.4987
# Epoch 295/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5002 - val_loss: 0.4986
# Epoch 296/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5003 - val_loss: 0.4987
# Epoch 297/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5002 - val_loss: 0.4986
# Epoch 298/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5086 - val_loss: 0.4986
# Epoch 299/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5004 - val_loss: 0.4987
# Epoch 300/300
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5056 - val_loss: 0.4987

# %% [markdown]
# Оцінимо точність класифікатора на даних, отриманих із кодувальника з нелінійною функцією активації tanh.

# %%
scores = score_algorithm(non_lin_encoder, lr,
                         X_train, y_train, X_test, y_test,
                         mode="encoder")

algorithms.append("Autoencoder (non-linear activation)")
train_accuracies.append(scores[0])
test_accuracies.append(scores[1])
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Train Accuracy: 0.8729
# Test Accuracy: 0.8433

# %% [markdown]
# ###Порівняння результатів за різними алгоритмами

# %% [markdown]
# Для порівняння результатів також отримаємо значення точності класифікатора при застосуванні всіх ознак.

# %%
scores = score_algorithm(None, lr,
                         X_train, y_train, X_test, y_test,
                         plot=False, mode="baseline")

algorithms.insert(0, "Baseline")
train_accuracies.insert(0, scores[0])
test_accuracies.insert(0, scores[1])
# Out:
# Train Accuracy: 0.8814
# Test Accuracy: 0.8667

# %% [markdown]
# Побудуємо діаграму точності алгоритмів під час тренування та тестування.

# %%
plot_accuracy(algorithms, train_accuracies, test_accuracies)

# %% [markdown]
# Порівняння результатів класифікації на даних зі зменшеною розмірністю демонструє суттєвий вплив методів зменшення розмірності на точність моделі. Базова модель логістичної регресії без застосування таких методів показала найкращий результат: точність 0.8814 на тренувальному наборі та 0.8667 на тестовому. Це свідчить про те, що усі вихідні дані містять корисну інформацію для класифікації.
#
# Методи головних компонент (PCA, Incremental PCA, Sparse PCA, Mini Batch Sparse PCA) призвели до незначного зниження точності. Найкращий результат серед них показав Sparse PCA (точність на тестовому наборі - 0.8633), що є найближчим до результату без застосування алгоритмів. Високу ефективність Sparse PCA можна пояснити здатністю цього методу відбирати найбільш значущі компоненти. Інші варіанти PCA, зокрема Incremental PCA (точність на тестовому наборі - 0.8500) та Mini Batch Sparse PCA (0.8567), мають дещо гірші показники, що може бути наслідком особливостей їх реалізації.
#
# Kernel PCA з RBF-ядром також продемонстрував високий рівень точності (0.8633 на тестовому наборі), що підтверджує ефективність нелінійних перетворень при виявленні складних структур в даних.
#
# Методи Truncated SVD та ICA мали гірші результати (точність на тестовому наборі 0.8467-0.8567), що може бути пов'язано з їхньою орієнтацією на пошук факторів, які не обов'язково відповідають найкращому розділенню класів. Лінійний дискримінантний аналіз (LDA) показав найгірший результат серед усіх досліджуваних методів (0.8300). Це може свідчити про те, що дані не зовсім відповідають припущенням методу або що дані мають нелінійну структуру.
#
# Результати автокодувальників залежать від вибору функції активації. Лінійний автокодувальник досяг точності 0.8533 на тестовому наборі, що є близьким до результатів PCA та Truncated SVD. Це підтверджує подібність цих підходів, адже автокодувальник з лінійними функціями активації є еквівалентним PCA. Нелінійний автокодувальник із функцією активації tanh продемонстрував нижчу точність (0.8433 на тестовому наборі). Це можна пояснити тим, що репрезентація даних через нелінійну функцію робиться занадто складною; функція tanh також може призводити до затухання градієнтів.

# %% [markdown]
# ##Висновок

# %% [markdown]
# У цій лабораторній роботі було проведено аналіз впливу методів зменшення розмірності на точність класифікації. Він демонструє, що базова модель логістичної регресії без зменшення розмірності показує найвищу точність, а методи PCA, Kernel PCA, Sparse PCA та автокодувальники можуть наблизити результати до початкових, хоча і помітне зменшення точності через втрату інформації.
#
# Лінійний автокодувальник демонструє результати, дуже близькі до методу PCA, що підтверджує їхню математичну еквівалентність. Нелінійний автокодувальник із функцією активації tanh показав гірший результат, що може свідчити про занадто складну репрезентацію даних для цього набору.
#
# Найкращі результати показали Sparse PCA та Kernel PCA, що пояснюється їхньою здатністю краще адаптуватися до особливостей даних. Методи факторного аналізу та LDA продемонстрували найгіршу точність, що може бути спричинено невідповідністю даних у наборі їхнім припущенням.
#
# Отримані результати підтверджують, що вибір методу зменшення розмірності суттєво впливає на продуктивність моделі, і що оптимальний підхід залежить від особливостей даних та задачі.

# %% [markdown]
# ##Джерело даних
# Waveform Database Generator (Version 1) - UCI Repository. Доступно за посиланням: https://archive.ics.uci.edu/ml/datasets/Waveform+Database+Generator+%28Version+1%29.
